# %% [markdown]
# <a href="https://colab.research.google.com/github/s-aleha/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/s-aleha/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My Lane
# I selected the **Content Optimization** lane because it focuses on improving the performance of web pages in search results. By analyzing search performance data, I can identify pages that may benefit from optimization and help prioritize improvement efforts. This lane is practical because it supports better decision-making using data rather than assumptions.

# %%
# Clone the repository to access the data.
# !git clone https://github.com/s-aleha/flyrank-ml-internship.git

# Change the current working directory to the cloned repository's root.
# This assumes the notebook is in 'work/notebooks/' within the repo.
import os
os.chdir('flyrank-ml-internship/work/notebooks/')

# Verify the new working directory and the presence of the data file.
print(os.getcwd())
print(os.listdir('../../data/'))
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 123 (delta 38), reused 90 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 15.72 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/flyrank-ml-internship/work/notebooks
# ['raw']

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Research Question

### Decision
Identify which pages should be optimized first.

### Action
Recommend updating or improving pages with low CTR despite receiving impressions.

### Cost of a Wrong Recommendation
If recommendations are incorrect, time and effort may be spent improving pages that would not significantly increase performance.

### Why ML?
Machine learning can identify patterns across many pages that are difficult to detect manually and help prioritize optimization opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os

# --- Start of environment setup for self-sufficiency ---
# This block ensures the repository is cloned and the CWD is set correctly,
# making this cell runnable even if previous setup cells haven't been executed.

repo_name = 'flyrank-ml-internship'
repo_url = f'https://github.com/s-aleha/{repo_name}.git'
expected_notebook_path_in_repo = os.path.join(repo_name, 'work', 'notebooks')
# Corrected filename within the 'raw' subdirectory
data_path_relative_to_notebook = '../../data/raw/content_refresh_anonymized.csv'

# Check if the repository is already cloned in /content/
if not os.path.exists(repo_name):
    print(f"Cloning {repo_name} from {repo_url}...")
    # !git clone {repo_url}
else:
    print(f"Repository '{repo_name}' already cloned.")

# Change current working directory to the expected location of the notebook within the repo
# This makes the relative path '../../data/raw/content_refresh_anonymized.csv' work as intended.
current_cwd = os.getcwd()
target_cwd = os.path.join('/content', expected_notebook_path_in_repo)

if current_cwd != target_cwd:
    if os.path.exists(target_cwd):
        os.chdir(target_cwd)
        print(f"Changed current working directory to: {os.getcwd()}")
    else:
        print(f"Warning: Expected notebook path '{target_cwd}' not found. Current CWD: {current_cwd}")
        print("Attempting to proceed, but data file might still be inaccessible.")

# Verify the data file path after changing directory (for debugging if error persists)
potential_data_filepath = os.path.abspath(data_path_relative_to_notebook)
if not os.path.exists(potential_data_filepath):
    print(f"Data file expected at: {potential_data_filepath}")
    print(f"Directory contents of '{os.path.dirname(potential_data_filepath)}':")
    try:
        print(os.listdir(os.path.dirname(potential_data_filepath)))
    except FileNotFoundError:
        print("  (Directory not found)")
# --- End of environment setup for self-sufficiency ---

# Now, try to read the CSV with the (hopefully) correct working directory
try:
    df = pd.read_csv(data_path_relative_to_notebook)

    print("\n--- Data Loaded Successfully ---")
    print("Rows:", len(df))
    print("Average CTR:", df["ctr"].mean())
    print("Average Position:", df["avg_position"].mean())

except FileNotFoundError as e:
    print(f"\nFATAL ERROR: Failed to load data even after setup attempt. {e}")
    print(f"Current working directory is: {os.getcwd()}")
    print(f"Attempted to read: {data_path_relative_to_notebook} which resolves to {os.path.abspath(data_path_relative_to_notebook)}")
    raise e # Re-raise to ensure the error is visible if it persists
except Exception as e:
    print(f"\nAn unexpected error occurred: {e}")
    raise e
# Out:
# Repository 'flyrank-ml-internship' already cloned.
#
# --- Data Loaded Successfully ---
# Rows: 30000
# Average CTR: 0.5107333333333334
# Average Position: 16.342380000000002

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Careful Words

This project will describe observed patterns in the available search data and provide decision-support for content optimization. The results may suggest useful trends, but they do not prove cause-and-effect relationships or explain how Google's search algorithm works. Any recommendations should be considered alongside human judgment and additional evidence.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
